# %%
import sys
#sys.path.append('../')
sys.path.insert(0,'../')
import writepw as exportpw
import numpy as np
import matplotlib.pyplot as plt

# %%
gausdist=np.random.normal(size=(1000,1000))

# %%
plt.scatter(gausdist[0],gausdist[1])

# %%
exportpw.write2DHist('test_hist2d.pw2',gausdist[0],gausdist[1],limits=[-3,3,-3,3,0,1],binSize=4)

# %%
temp='teststring'

# %%
bytes(temp,'utf-8')
# Out:
# b'teststring'
